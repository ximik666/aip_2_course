# %% [markdown]
# Стек
#
# Стек — это коллекция, элементы которой получают по принципу «последний вошел, первый вышел» (Last-In-First-Out или LIFO). Это значит, что мы будем иметь доступ только к последнему добавленному элементу.
#
# В отличие от списков, мы не можем получить доступ к произвольному элементу стека. Мы можем только добавлять или удалять элементы с помощью специальных методов.
#
# Стек - структура данных с доступом к элементам по принципу LIFO (Last In First Out - Последний пришел - первый вышел). Данные добавляются в начало (конец, кому как удобно), оттуда же и извлекаются. Для реализации данной структуры достаточно иметь лишь две функции и указатель на верхушку:
#
# push(List); //добавляет данные в стек
#
# pop_item(List); //извлекает последний элемент
#
# ![](https://evileg.com/media/users/Lila25mila/photos/photo_ILE5mbe.jpg)

# %% [markdown]
# Очередь - структура данных с доступом к элементам по принципу FIFO (First In First Out - Первый пришел - Первый вышел). Данные добавляются в конец, а извлекаются из начала.
#
# push(List); //добавляет данные в конец очереди
#
# pop_item(List); //извлекает первый элемент из очереди
#
# ![](https://media.proglib.io/wp-uploads/2018/08/4.png)

# %% [markdown]
# Вам необходимо проверить, в правильном ли порядке расставлены {}, (), [], <>. Вместе с ними может идти и другой текст, поэтому вам стоит заняться фильтрацией строки.
#
# # Примеры:
#
# # valid_bracket("(some_data)")
# # valid_bracket("() [ww]1{}<>")
# # valid_bracket("< [ ( { })]>")
# # valid_bracket("(]")
# # valid_bracket("([9)]")
#
# Задачу необходимо реализовать с помощью стека
